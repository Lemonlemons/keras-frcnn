# %%
# %matplotlib inline
# %run test_frcnn.py --gpu 0 --path ~/Projects/sea_lions/input/AnotherMini/
# Out:
# Using TensorFlow backend.
# {0: 'sealion', 1: 'bg'}
# (?, ?, ?, 3)
# hello
# (?, ?, ?, 1024)
# (?, ?, ?, 512)
# (?, ?, ?, 9)
# (?, ?, ?, 36)
# (1, 100, 14, 14, 1024)
# 126_00.jpg
# [('sealion', 93.734908103942871), ('sealion', 81.430327892303467)]
# []
# [('sealion', 93.638169765472412)]
# [('sealion', 96.098244190216064), ('sealion', 93.782442808151245), ('sealion', 85.715979337692261)]
# [('sealion', 84.491658210754395)]
# [('sealion', 90.249031782150269), ('sealion', 88.664054870605469), ('sealion', 86.508160829544067), ('sealion', 82.477712631225586)]
# [('sealion', 97.395330667495728), ('sealion', 94.776540994644165), ('sealion', 94.45270299911499)]
# [('sealion', 95.615303516387939), ('sealion', 91.627001762390137), ('sealion', 83.019036054611206), ('sealion', 81.226998567581177)]
# [('sealion', 82.31627345085144)]
# [('sealion', 83.252108097076416), ('sealion', 82.549035549163818)]
# [('sealion', 83.891004323959351), ('sealion', 80.434072017669678)]
# ...
